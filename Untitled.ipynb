# %%
import tkinter as tk
root = tk.Tk()

def win():

    redbutton1 = fr2.Button(fr2, text="Red", fg="red")
    redbutton1.place(relx=.5, rely=.5, anchor="c")
    fr2.pack(fill=None, expand=False)


def newwin():
    fr3= tk.Frame(root, width=100, height=100, background="bisque")
    fr3.pack(fill=None, expand=False)
    redbutton2 = tk.Button(fr3, text="yellow", fg="yellow")
    redbutton2.place(relx=.5, rely=.5, anchor="c")

fr1 = tk.Frame(root, width=50, height = 50, background="#b22222")
fr1.pack(side = tk.LEFT)

fr2= tk.Frame(root, width=100, height=100, background="bisque")

redbutton3 = tk.Button(fr1, text="Red", fg="red",command = win)
redbutton3.pack(fill=None, expand=False)

yellowbuton = tk.Button(fr1, text="yellow", fg="yellow",command = newwin)
yellowbuton.pack(fill=None, expand=False)

fr2 = root.frame()



root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Software3\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-8-4051d3734a2f>", line 6, in win
#     redbutton1 = fr2.Button(fr2, text="Red", fg="red")
# AttributeError: 'str' object has no attribute 'Button'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Software3\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-8-4051d3734a2f>", line 6, in win
#     redbutton1 = fr2.Button(fr2, text="Red", fg="red")
# AttributeError: 'str' object has no attribute 'Button'

# %%
hello()

# %%
import tkinter as tk
class hello:
    def __init__(self):
        self.root = tk.Tk()


        def win():

            self.redbutton1 = tk.Button(self.fr2, text="Red", fg="red")
            self.redbutton1.place(relx=.5, rely=.5, anchor="c")
            self.fr2.pack(fill=None, expand=False)

        def newwin():
            self.fr3= tk.Frame(self.root, width=100, height=100, background="bisque")
            self.fr3.pack(fill=None, expand=False)
            self.redbutton2 = tk.Button(self.fr3, text="yellow", fg="yellow")
            self.redbutton2.place(relx=.5, rely=.5, anchor="c")

        self.fr1 = tk.Frame(self.root, width=50, height = 50, background="#b22222")
        self.fr1.pack(side = tk.LEFT)

        self.fr2= tk.Frame(self.root, width=100, height=100, background="bisque")
        

        self.redbutton3 = tk.Button(self.fr1, text="Red", fg="red",command = win)
        self.redbutton3.pack(fill=None, expand=False)

        self.yellowbuton = tk.Button(self.fr1, text="yellow", fg="yellow",command = newwin)
        self.yellowbuton.pack(fill=None, expand=False)

        self.fr2 = self.root.frame()



        self.root.mainloop()

# %%
hello()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Software3\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-6-1f903d39dcb7>", line 9, in win
#     self.redbutton1 = tk.Button(self.fr2, text="Red", fg="red")
#   File "C:\Software3\Anaconda3\lib\tkinter\__init__.py", line 2369, in __init__
#     Widget.__init__(self, master, 'button', cnf, kw)
#   File "C:\Software3\Anaconda3\lib\tkinter\__init__.py", line 2292, in __init__
#     BaseWidget._setup(self, master, cnf)
#   File "C:\Software3\Anaconda3\lib\tkinter\__init__.py", line 2262, in _setup
#     self.tk = master.tk
# AttributeError: 'str' object has no attribute 'tk'

# %%
import tkinter as tk
from tkinter import ttk

class Aplikacja(tk.Frame):
    def __init__(self, parent):
        tk.Frame.__init__(self, parent)
        self.grid()

        zakladki=ttk.Notebook(parent)
        entries = {}
        for title in ('Czapki', 'Dodatki', 'buty', 'spodnie', 'kurtka',
                      'T-shirt', 'sweter', 'skarpetki', 'koszula'):
            frame = ttk.Frame(zakladki)
            for row, txt in (0, 'Nazwa'), (1, "Kolor"), (2, "Firma"):
                tk.Label(frame, text=txt).grid(row=row, column=0)
                entry = tk.Entry(frame)
                entries[title, txt] = entry
                entry.grid(row=row, column=1)
            zakladki.add(frame, text=title)
        zakladki.grid()

root= tk.Tk()
root.title("Szaffa")
app= Aplikacja(root)
root.mainloop()

# %%
from tkinter import *
from tkinter import ttk
import tkinter.messagebox
import tkinter as tk
 
 
class Root(Tk):
    def __init__(self):
        super(Root, self).__init__()
        self.title("Application")
        self.minsize(640, 400)
        self.configure(background="white")
 
        self.createMenu()
 
        tabControl = ttk.Notebook(self)
        self.tab1 = ttk.Frame(tabControl)
        tabControl.add(self.tab1, text="tab 1")
 
        self.tab2 = ttk.Frame(tabControl)
        tabControl.add(self.tab2, text="tab 2")
 
        self.tab3 = ttk.Frame(tabControl)
        tabControl.add(self.tab3, text="tab 3")
 
        self.tab4 = ttk.Frame(tabControl)
        tabControl.add(self.tab4, text="tab 4")
        self.addingTab4()
 
        self.tab5 = ttk.Frame(tabControl)
        tabControl.add(self.tab5, text="tab 5")
 
 
        self.tab6 = ttk.Frame(tabControl)
        tabControl.add(self.tab6, text="tab 6")
 
 
        self.tab7 = ttk.Frame(tabControl)
        tabControl.add(self.tab7, text="Tab 7")
 
        tabControl.pack(expand=1, fill="both")
 
    def startpressed(self):
        new = tk.Toplevel(self)
        new.minsize(640, 400)
        new.geometry('500x300')
        new.configure(background="white")
        tabControl1 = ttk.Notebook(new)
        new.tab1 = ttk.Frame(tabControl1)
        tabControl1.add(new.tab1, text="tab 1")
        tabControl1.pack(expand=1, fill="both")
 
    def createMenu(self):
        menubar = Menu(self)
        self.config(menu=menubar)
 
        file_menu = Menu(menubar, tearoff=0)
        menubar.add_cascade(label="File", menu=file_menu)
        file_menu.add_command(label="Exit")
 
        help_menu = Menu(menubar, tearoff=0)
        menubar.add_cascade(label="Help", menu=help_menu)
        help_menu.add_command(label="About Us")
 
 
    def addingTab4(self):
        Label(self.tab4, text= "Please Select your choice" ).place(x= 250, y= 20)
        submit = Button(self.tab4, text="Submit", command=lambda: self.submit()).place(x=520, y=320)
 
 
    def submit(self):
        newTop = Toplevel(self.master)
        display = Label(newTop, text="Review").pack()
        newTop.title("Review and Submit")
        newTop.focus_set()
        newTop.geometry("400x600")
        # WOULD LIKE: when this button is clicked it takes the user to tab 7 of the notebook window
        btnResult = Button(newTop, text="Tab 7").pack()
        btnBack = Button(newTop, text="Back").pack()
 
 
root = Root()
root.mainloop()

# %%
import tkinter as tk
class hello:
    def __init__(self):
        self.root = tk.Tk()


        def win():
            self.fr2= tk.Frame(self.root, width=100, height=100, background="bisque")
            self.fr2.pack(fill=None, expand=False)
            self.redbutton1 = tk.Button(self.fr2, text="Red", fg="red")
            self.redbutton1.place(relx=.5, rely=.5, anchor="c")

        def newwin():
            self.fr3= tk.Frame(self.root, width=100, height=100, background="bisque")
            self.fr3.pack(fill=None, expand=False)
            self.redbutton2 = tk.Button(self.fr3, text="yellow", fg="yellow")
            self.redbutton2.place(relx=.5, rely=.5, anchor="c")

        self.fr1 = tk.Frame(self.root, width=50, height = 50, background="#b22222")
        self.fr1.pack(side = tk.LEFT)



        self.redbutton3 = tk.Button(self.fr1, text="Red", fg="red",command = win)
        self.redbutton3.pack(fill=None, expand=False)

        self.yellowbuton = tk.Button(self.fr1, text="yellow", fg="yellow",command = newwin)
        self.yellowbuton.pack(fill=None, expand=False)

        self.fr2 = self.root.frame()



        self.root.mainloop()

# %%
from tkinter import *
import tkinter.ttk as ttk
s=ttk.Style()
print('Style themes on my system are ', s.theme_names())
s.theme_use('clam')
s.configure('bb.TButton', background='white', padding=50)
b1=ttk.Button(text='Default')
b1.pack(side=LEFT, anchor=S, padx=[0,40])
b2=ttk.Button(text='Custom', style='bb.TButton')
b2.pack(side=RIGHT, anchor=S, padx=[20,0])
# Out:
# Style themes on my system are  ('winnative', 'clam', 'alt', 'default', 'classic', 'vista', 'xpnative')

# %%
from tkinter import * 
selection_window = Tk()
selection_window.wm_title("")
selection_window.geometry('{}x{}'.format(200, 150))
frame_1 = Frame(selection_window, width=200, height=30)
frame_1.pack()
Button(frame_1, text="Single",height = 10).pack(side=LEFT, anchor=S, padx=[0,40])
Button(frame_1,text="Range",command=Toplevel,height = 2).pack(side=RIGHT, anchor=S, padx=[20,0])
selection_window.mainloop()
